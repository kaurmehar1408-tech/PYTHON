# %%
#DAY-1      {Packages,comments}
print("Hello world");  #print is a function
# Out:
# Hello world

# %%
# PIP
# !pip install flask 
# pip is the package manager of python.
# by using this we can instal external modules on our system.
# there are 2 types of modules in python:
# a) Builtin modules: preinstalled with python.
# b) External modules: need to be installed using pip.

# %%
#COMMENTS: They are used to write something which the programmer doesnot want to execute.
# They used to explain code, mark something or add some notes.

# This is a single-line comment

"""
This is a multi-line
comment !!
"""
# Out:
# '\nThis is a multi-line\ncomment !!\n'

# %%
# DAY-2 
# A variable is the name given to memory location in a program.
a = 30
b = "hello"
c = 75.4125
d  = True

# %%
# type() function 
a = 31
type(a)

b = "54"
type(b)

c = True
type(c)

d = 86.21
type(d)
# Out:
# float

# %%
# Typecasting
a = str(31)
b = int("32")
c = float(32)
print(type(a))
print(type(b))
print(c)
# Out:
# <class 'str'>
# <class 'int'>
# 32.0

# %%
# Input() function => This function allows the user to take input from the keyboard as a string.
# ALways remember that the output of input is always a string even if a number is entered.
# name = input("Enter your name: ")
# print("Hello",name)

# %%
# PRACTICE-SET
# 1)
# a = int(input("Enter first number: "))
# b = int(input("Enter second number: "))
# c = a + b
# print("Sum of the two numbers that you entered is: ",c)

# %%
# 2)
# a = int(input("Enter first number: "))
# b = int(input("Enter second number: "))
# c = a % b
# print("Remainder: ",c)

# %%
# 3)
# a = input("Enter something: ")
# print(type(a))

# %%
# 4) 
a = 34
b = 80
if(a > b):
    print("a is greater")

else:
    print("b is greater")
# Out:
# b is greater

# %%
# 5)
# a = int(input("Enter first number: "))
# b = int(input("Enter second number: "))
# c = (a + b) / 2
# print("Average of the two numbers that you entered is: ",c)

# %%
# 6)
# a = int(input("Enter a number: "))
# c = a * a
# print("Square of the number that you entered is: ",c)

# %%
# Day-3  {STRINGS}
a = 'abc'
b = "abc"
c = '''abc'''

# %%
# word = "amazing"
# print(word[1:6:2])
# print(word[-7:-1])
# print(word[:7])
# print(word[0:])

# %%
# str = "gratitude"
# print(len(str))
# print(str.endswith("de"))
# count = str.count("g")
# print(count)
# capital = str.capitalize()
# print(capital)
# index = str.find("r")
# print(index)
# replaced = str.replace("g","s")
# print(replaced)

# %%
# PRACTICE-SET
# 1) 
# name = input("Enter your name: ")
# print("Good Afternoon",name)

# %%
#2)
# name = input("Enter your name: ")
# print("Dear",name,"You are selected !")

# %%
# 3)
# text = input("Enter a sentence: ")
# if " " in text:
#     print("Yes! found a double space")
# else:
#     print("No double spaces found")

# %%
# 4)
# print("Dear Harry, this python course is nice. Thanks!")
